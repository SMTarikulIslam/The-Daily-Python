# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
# Your code here
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
# Your code here
number = input("Enter a number")
print(number)
# Out:
# 55

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
# Your code here
number = float(input("Enter a number"))

if number >0:
    print("It's a positive number")
elif number <0:
    print("It's a negative number")
else:
    print("It's zero")
# Out:
# It's zero

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
# Your code here

number1 = float(input("Enter the first number"))
number2 = float(input("Enter the second number"))
number3 = float(input("Enter the third number"))

if number1>number2 and number1>number3:
    print("The largest number is: ", number1)
elif number2>number3 and number2>number1:
    print("The largest number is: ", number2)
else:
    print("The largest number is ", number3)
# Out:
# The largest number is  24.0

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
# Your code here
def factorial(n):
    if n == 0:
        return 1
    else:
        return n * factorial(n-1)

number = int(input("Enter a number"))
print(f"The factorial of {number} is {factorial(number)}")
# Out:
# The factorial of 25 is 15511210043330985984000000

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
# Your code here
Name = "Tarikul Islam" ##String 
Age = 24 ##Integer
Height = 5.10 #Float
Bool_Var = True

print(f"The integer value: {Age}, The type is {type(Age)}")
print(f"The String value: {Name}, The type is {type(Name)}")
print(f"The Boolean value: {Bool_Var}, The type is {type(Bool_Var)}")
print(f"The float value: {Height}, The type is {type(Height)}")
# Out:
# The integer value: 24, The type is <class 'int'>
# The String value: Tarikul Islam, The type is <class 'str'>
# The Boolean value: True, The type is <class 'bool'>
# The float value: 5.1, The type is <class 'float'>

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
# Your code here

A = 10
B = 5.7
## Before Swap 

print(f"The value of A is {A} and The value of B is {B}")

## After swap

A , B = B , A 
print(f"The value of A is {A} and the value of B is {B}")
# Out:
# The value of A is 10 and The value of B is 5.7
# The value of A is 5.7 and the value of B is 10

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
# Your code here
Celsius = float(input("Enter the temperature in celsius"))
Fahrenheit = (Celsius*(9/5)) +32 
print(f"The temperature in celsius is {Celsius}, and the temperature in fahrenheit is {Fahrenheit}")
# Out:
# The temperature in celsius is 32.0, and the temperature in fahrenheit is 89.6

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
# Your code here
string1 = "Tarikul"
string2 = "Islam"
concatenated_string = string1 + " " + string2

print(concatenated_string)
# Out:
# Tarikul Islam

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
# Your code here
var =10.5
if isinstance(var, float):
    print(f"{var} is a float")
else:
    print(f"{var}is not a float")
# Out:
# 10.5 is a float

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
# Your code here

Number1 = float(input("Enter the First Number"))
Number2 = float(input("Enter the Second Number"))

Addition = Number1 + Number2
Subtraction = Number1 - Number2 
Multiplication = Number1 * Number2 
Division = Number1/Number2 

print(f"Addition: {Addition}")
print(f"Subtraction: {Subtraction}")
print(f"Multiplication: {Multiplication}")
print(f"Division: {Division}")
# Out:
# Addition: 133.0
# Subtraction: -23.0
# Multiplication: 4290.0
# Division: 0.7051282051282052

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
# Your code here
Num1 = float(input("Enter the first value: "))
Num2 = float(input("Enter the second value: "))

if (Num1 == Num2):
    print("Both are equal")
elif (Num1!= Num2):
    if (Num1>Num2):
        print("First Number is greater than the Second Number")
    elif (Num1<Num2):
        print("First Number is less than the second number")
print("They are not equal")
# Out:
# First Number is less than the second number
# They are not equal

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
# Your code here
v1 = True
v2 = False

print(v1 and v2)
print(v1 or v2)
print(not v2)
print(not v1)
# Out:
# False
# True
# True
# False

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
# Your code here
Value = float(input("Enter an integer value: "))

square = Value ** 2

print(f" The Square value is {square}")
# Out:
#  The Square value is 27.040000000000003

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
# Your code here
x = int(input("Enter an integer"))

if x % 2 == 0:
    print(f"{x} is even number")
else:
    print(f"{x} is odd number")
# Out:
# 0 is even number

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
# Your code here
N = int (input("Enter the number: "))

Sum = (N * (N + 1)) / 2
print(f"The sum of the first {N} natural number: {Sum} ")
# Out:
# The sum of the first 56 natural number: 1596.0

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
# Your code here
# Is the year divisible by 400?
#    ├── Yes → Leap Year
##         ↓
#Is the year divisible by 100?
#    └── No
 #        ↓
#Is the year divisible by 4?
#    ├── Yes → Leap Year
##    └── No → Not a Leap Year


year = int(input("Enter a year: "))

if(year % 400 == 0):
    if(year % 100 == 0):
        if(year % 4 == 0):
            print(f"{year} is leap year")
else:
    print(f"{year} is Not leap year")
# Out:
# 2000 is leap year

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
# Your code here
string = input("Write a string: ")
reversed_string = string [::-1]
print(f"The reversed string is: {reversed_string} ")
# Out:
# The reversed string is: tafiR

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
# Your code here
string = input("Write a string: ")
if string == string [::-1] :
    print(f" {string} is a palindrome.")
else:
    print(f" {string} is not a palindrome. ")
# Out:
#  Rifat is not a palindrome.

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
# Your code here
numbers = [int(x) for x in input("Enter numbers separated by space: ").split()]
numbers.sort()
print(f"Sorted list: {numbers}")
# Out:
# Sorted list: [412012]
