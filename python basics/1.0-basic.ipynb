# %% [markdown]
# ###Syntax and Semantics in Python

# %% [markdown]
# *Single line comments and multiline comments
# *Definition of Syntax and Semantics
# *Basic Syntax rules in Python
# *Understanding semantics in python
# *Command syntax error and how to avoid them
# *Practice code examples

# %%
## Basic Syntax Rules In Python
## Case sensitivity- Python is case sensitive 

name="Tarikul"
Name="Islam"

print(name)
print(Name)
# Out:
# Tarikul
# Islam

# %%
## Indentation 
## Python uses indentation to define of code. Consistent use of spaces(commonly 4) or a tab is required.

age=32 
if age>32: 

    print(age)

print(age)
# Out:
# 32

# %%
## single line comment
print("Hello World")
# Out:
# Hello World

# %%
## line Continuation 
## Use a backslash (\) to continue a statement to the next line

total= 1+2+3+4+5+6+7+\
4+5+6

print(total)
# Out:
# 43

# %%
## Multiple Statement on a single line 
x=5; y=10; z=x+y
print(z)
# Out:
# 15

# %%
## Understand Semantics In Python 
# Variable Assignment 
age = 32 ## age is an integer 
name ="Krish" ## Name is a string

# %%
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
## Type Inference 
variable=10
print(type(variable))
variable ="krish"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
age =32
if age>30:
    print(age)
# Out:
# 32

# %%
## Code examples of indentation
if True:
    print("Correct Indentation")
    if False:
        print("This is not print")
    print("This will print")
print("Outside the if block")
# Out:
# Correct Indentation
# This will print
# Outside the if block
