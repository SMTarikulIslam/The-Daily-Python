# %% [markdown]
# Dictionaries in python

# %% [markdown]
# 1. Introduction of dictionaries
# 2. Creating dictionaries
# 3. Accessing Dictionaries Elements
# 4. Modifying Dictionaries Elements
# 5. Dictionary Methods
# 6. Iterating over dictionaries
# 7. Nested Dictionaries
# 8. Dictionary Comprehensions
# 9. Practical Examples and common errors

# %%
## Dictionaries are unordered collections of items. They store data in key-value pairs. Keys must be unique and immutable(e.g strings, numbers, or tuples) while values can of any type.

# %%
## Creating Dictionary 
empty_dict ={}
print(type(empty_dict))
# Out:
# <class 'dict'>

# %%
empty_dict = dict()
empty_dict
# Out:
# {}

# %%
student = {"Name": "Tarikul","age": 25, "grade": 2.5 }
print(student)
print(type(student))
# Out:
# {'Name': 'Tarikul', 'age': 25, 'grade': 2.5}
# <class 'dict'>

# %%
# Single key is always used 
student = {"name":"Tarikul", "age":25, "name":2.5}
print(student)
# Out:
# {'name': 2.5, 'age': 25}

# %%
## accessing dictionary elements 
student = {"name": "Tarikul", "age": 25, "grade": 'A'}
print(student)
# Out:
# {'name': 'Tarikul', 'age': 25, 'grade': 'A'}

# %%
## Accessing dictionary elements 
print(student['grade'])
print(student['age'])


## Accessing using get() method
print(student.get('grade'))
print(student.get('last_name'))
print(student.get('last_name',"Not available"))
# Out:
# A
# 25
# A
# None
# Not available

# %%
## Modifying Dictionary Elements
## Dictionary are mutable, so you can add, update or delete elements
print(student)
# Out:
# {'name': 'Tarikul', 'age': 25, 'grade': 'A'}

# %%
student["age"] = 33 ## Update value for the key
print(student)
student["address"]="Bangladesh" ## Added a new key and value
print(student)
# Out:
# {'name': 'Tarikul', 'age': 33, 'grade': 'A'}
# {'name': 'Tarikul', 'age': 33, 'grade': 'A', 'address': 'Bangladesh'}

# %%
del student['grade'] ##Delete key and value pair
print(student)
# Out:
# {'name': 'Tarikul', 'age': 33, 'address': 'Bangladesh'}

# %%
##Dictionary methods

keys = student.keys() ## get all values 
print(keys)
values = student.values() ## get all values 
print(values)

items = student.items() ## get all key value pair
print(items)
# Out:
# dict_keys(['name', 'age', 'address'])
# dict_values(['Tarikul', 33, 'Bangladesh'])
# dict_items([('name', 'Tarikul'), ('age', 33), ('address', 'Bangladesh')])

# %%
## Shallow copy
student_copy = student
print(student)
print(student_copy)
# Out:
# {'name': 'Tarikul', 'age': 33, 'address': 'Bangladesh'}
# {'name': 'Tarikul', 'age': 33, 'address': 'Bangladesh'}

# %%
student["name"] = "Tarikul2"
print(student)
print(student_copy)
# Out:
# {'name': 'Tarikul2', 'age': 33, 'address': 'Bangladesh', 'Name': 'Tarikul2'}
# {'name': 'Tarikul2', 'age': 33, 'address': 'Bangladesh', 'Name': 'Tarikul2'}

# %%
student_copy1 = student.copy()
print(student_copy1)
print(student)
# Out:
# {'name': 'Tarikul2', 'age': 33, 'address': 'Bangladesh', 'Name': 'Tarikul2'}
# {'name': 'Tarikul2', 'age': 33, 'address': 'Bangladesh', 'Name': 'Tarikul2'}

# %%
student["name"] = "Tarikul3"
print(student_copy1)
print(student)
# Out:
# {'name': 'Tarikul2', 'age': 33, 'address': 'Bangladesh', 'Name': 'Tarikul2'}
# {'name': 'Tarikul3', 'age': 33, 'address': 'Bangladesh', 'Name': 'Tarikul2'}

# %%
## Iterating over dictionary 
## You can use loops to iterate over dictionaries, keys, values, or items
## Iterating over keys 

for keys in student.keys():
    print(keys)
# Out:
# name
# age
# address
# Name

# %%
## Iterate over values 
for value in student.values():
    print(value)
# Out:
# Tarikul3
# 33
# Bangladesh
# Tarikul2

# %%
## Iterating over key value pair
for key, value in student.items():
    print(f"{key}:{value}")
# Out:
# name:Tarikul3
# age:33
# address:Bangladesh
# Name:Tarikul2

# %%
## Nested Dictionaries 
students ={
    "student1":{"name":"Tarikul", "age":32},
    "student2":{"name":"Rifat", "age":25}

}

print(students)
# Out:
# {'student1': {'name': 'Tarikul', 'age': 32}, 'student2': {'name': 'Rifat', 'age': 25}}

# %%
## Access nested dictionaries elements 
print(students["student2"]["name"])
print(students["student2"]["age"])
# Out:
# Rifat
# 25

# %%
students.items()
# Out:
# dict_items([('student1', {'name': 'Tarikul', 'age': 32}), ('student2', {'name': 'Rifat', 'age': 25})])

# %%
# Iterating over nested dictionaries
for student_id, student_info in student.items():
    print(f"{student_id}:{student_info}")

    for key,value in student_info.items():
        print(f"{key}:{value}")
# Out:
# name:Tarikul3
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 5
#       1 # Iterating over nested dictionaries
#       2 for student_id, student_info in student.items():
#       3     print(f"{student_id}:{student_info}")
#       4
# ----> 5     for key,value in student_info.items():
#       6         print(f"{key}:{value}")
#       7
#
# AttributeError: 'str' object has no attribute 'items'

# %%
##Dictionary_Comphrehension

evens = {x:x**2 for x in range(10) if x%2==0}
print(evens)
# Out:
# {0: 0, 2: 4, 4: 16, 6: 36, 8: 64}

# %%
## Practical examples 
## Use a dictionary to count the frequency of elements in list

numbers = [1,2,2,3,3,3,4,4,4,4]
frequency = {}

for number in numbers:
    if number in frequency: 
        frequency[number]+=1
    else: 
        frequency[number]=1
print(frequency)
# Out:
# {1: 1, 2: 2, 3: 3, 4: 4}

# %%
## Marge 2 dictionaries into one
dict1 ={"a":1, "b":2}
dict2 ={"b":3, "d":4}

merged_dict={**dict1, **dict2}
print(merged_dict)
# Out:
# {'a': 1, 'b': 3, 'd': 4}
